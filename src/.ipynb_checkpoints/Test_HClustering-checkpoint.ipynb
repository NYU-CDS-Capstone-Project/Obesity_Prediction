# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.decomposition import PCA
from sklearn.preprocessing import normalize
from sklearn.cluster import AgglomerativeClustering

# %%
X = pd.read_csv('../ChangedDataSource.csv')
y = pd.read_csv('../ChangedTarget.csv')

X.drop(['ID'], axis = 1, inplace = True)
y_vector = []
for colname in y:
    if colname != 'ID':
        y_vector.append(y[colname].values)

# Use only the 4th entry in y_vector as target
X_total, y_total = X.values, y_vector[4]

# PCA of X_total
pca2 = PCA(2)
PCA2_X_test = pca2.fit_transform(X_total)

fig_unclustered = plt.figure()
plt.scatter(PCA2_X_test[:, 0], PCA2_X_test[:, 1], alpha=0.3)
plt.show()

# %%
outlier_i = []

for i in range(len(PCA2_X_test)):
    if PCA2_X_test[i][0] > 600:
        outlier_i.append(i)

X_total = np.delete(X_total, outlier_i, axis=0)
X_01norm = np.array(X_total)
X_Gnorm = np.array(X_total)

# 0-1 normalization
for i in range(len(X_01norm[0])):
    curmin, curmax = min(X_01norm[:, i]), max(X_01norm[:, i])
    if curmin == curmax:
        X_01norm[:, i] -= curmin
    else:
        X_01norm[:, i] = (X_01norm[:, i] - curmin) / (curmax - curmin)
print (X_01norm)
print (X_Gnorm)
# Out:
# [[0.         0.         0.         ... 0.46354085 0.58780516 0.49145861]
#  [0.         0.         0.         ... 0.45913047 0.57089133 0.49210158]
#  [0.         0.         0.         ... 0.45913047 0.57089133 0.65125975]
#  ...
#  [0.         0.         0.         ... 0.45913047 0.57089133 0.48747245]
#  [0.         0.         0.         ... 0.45913047 0.57089133 0.51708914]
#  [0.         0.         0.         ... 0.45913047 0.55990338 0.39973585]]
# [[ 0.          0.          0.         ...  0.04619305  0.17342962
#    0.18341062]
#  [ 0.          0.          0.         ...  0.          0.
#    0.18934808]
#  [ 0.          0.          0.         ...  0.          0.
#    1.65906361]
#  ...
#  [ 0.          0.          0.         ...  0.          0.
#    0.14660123]
#  [ 0.          0.          0.         ...  0.          0.
#    0.42009083]
#  [ 0.          0.          0.         ...  0.         -0.11266728
#   -0.66358558]]

# %%
pca2 = PCA(2)
PCA2_X = pca2.fit_transform(X_01norm)

fig_unclustered_normalized = plt.figure()
plt.scatter(PCA2_X[:, 0], PCA2_X[:, 1])
plt.show()

# %%
pca3 = PCA(3)
PCA3_X = pca3.fit_transform(X_01norm)

fig_unclustered3d = plt.figure()
ax = Axes3D(fig_unclustered3d)
ax.scatter(PCA3_X[:, 0], PCA3_X[:, 1], PCA3_X[:, 2])
plt.show()

# %%
# Use sklearn preprocessing (Gaussian normalization)
X_Gnorm = normalize(X_Gnorm, axis = 0)
PCA2G_X = pca2.fit_transform(X_Gnorm)

fig_unclustered_G_normalized = plt.figure()
plt.scatter(PCA2G_X[:, 0], PCA2G_X[:, 1])
plt.show()

# %%
# Perform Hierarchical Clustering using AgglomerativeClustering in sklearn
ks = [3] #[3, 4, 5] ?
for k in ks:
    # Try different linkage criterions
    complete = AgglomerativeClustering(n_clusters = k, linkage = 'complete').fit(X_Gnorm)
    average = AgglomerativeClustering(n_clusters = k, linkage = 'average').fit(X_Gnorm)
    ward = AgglomerativeClustering(n_clusters = k, linkage = 'ward').fit(X_Gnorm)
    
    complete_label = complete.labels_
    average_label = average.labels_
    ward_label = ward.labels_
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-bab10e85af44> in <module>()
#       3 for k in ks:
#       4     # Try different linkage criterions
# ----> 5     complete = AgglomerativeClustering(n_clusters = k, linkage = 'complete').fit(X_total)
#       6     average = AgglomerativeClustering(n_clusters = k, linkage = 'average').fit(X_total)
#       7     ward = AgglomerativeClustering(n_clusters = k, linkage = 'ward').fit(X_total)
#
# /Users/daoyangshan/anaconda/lib/python3.6/site-packages/sklearn/cluster/hierarchical.py in fit(self, X, y)
#     828             memory.cache(tree_builder)(X, connectivity,
#     829                                        n_clusters=n_clusters,
# --> 830                                        **kwargs)
#     831         # Cut the tree
#     832         if compute_full_tree:
#
# /Users/daoyangshan/anaconda/lib/python3.6/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     327
#     328     def __call__(self, *args, **kwargs):
# --> 329         return self.func(*args, **kwargs)
#     330
#     331     def call_and_shelve(self, *args, **kwargs):
#
# /Users/daoyangshan/anaconda/lib/python3.6/site-packages/sklearn/cluster/hierarchical.py in _complete_linkage(*args, **kwargs)
#     582 def _complete_linkage(*args, **kwargs):
#     583     kwargs['linkage'] = 'complete'
# --> 584     return linkage_tree(*args, **kwargs)
#     585
#     586
#
# /Users/daoyangshan/anaconda/lib/python3.6/site-packages/sklearn/cluster/hierarchical.py in linkage_tree(X, connectivity, n_components, n_clusters, linkage, affinity, return_distance)
#     468             i, j = np.triu_indices(X.shape[0], k=1)
#     469             X = X[i, j]
# --> 470         out = hierarchy.linkage(X, method=linkage, metric=affinity)
#     471         children_ = out[:, :2].astype(np.int)
#     472
#
# /Users/daoyangshan/anaconda/lib/python3.6/site-packages/scipy/cluster/hierarchy.py in linkage(y, method, metric, optimal_ordering)
#     706                          'matrix looks suspiciously like an uncondensed '
#     707                          'distance matrix')
# --> 708         y = distance.pdist(y, metric)
#     709     else:
#     710         raise ValueError("`y` must be 1 or 2 dimensional.")
#
# /Users/daoyangshan/anaconda/lib/python3.6/site-packages/scipy/spatial/distance.py in pdist(X, metric, *args, **kwargs)
#    1717             pdist_fn = getattr(_distance_wrap,
#    1718                                "pdist_%s_%s_wrap" % (metric_name, typ))
# -> 1719             pdist_fn(X, dm, **kwargs)
#    1720             return dm
#    1721
#
# KeyboardInterrupt:
